# %% [markdown]
# <a href="https://colab.research.google.com/github/TanujaMohitkar/Amazon_Prime_Analysis/blob/main/Amazon_prime_TV_Shows_and_Movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Project Name**    - Amazon Prime TV Shows and Movies Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Project by**      - Tanuja Raju Mohitkar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The Amazon Prime Video Content Analysis project is based on exploring the movies and TV shows available on Amazon Prime Video. Today, online streaming platforms have become a major source of entertainment, and platforms like Amazon Prime offer a large variety of content from different countries, languages, genres, and time periods. The main purpose of this project is to understand the content available on the platform and find useful patterns and trends by analyzing the data.
#
# The project starts with understanding the dataset and the information provided for each movie or TV show. The dataset contains details such as title, type of content, director, cast, country, release year, date added, rating, duration, and genre. Before starting the actual analysis, the data needs to be checked and cleaned. This includes finding missing values, checking for duplicate records, correcting data types, and identifying any inconsistent information. Cleaning the data is important because it helps make sure that the results of the analysis are accurate.
#
# After cleaning the dataset, I perform Exploratory Data Analysis (EDA) to understand the different characteristics of Amazon Prime's content library. One of the first things I look at is the number of movies and TV shows available. This helps in understanding which type of content is more common on the platform. I also analyze the release years to see how the content library has changed over time and whether Amazon Prime has been adding more recent content.
#
# Another important part of the analysis is understanding the different genres available on the platform. By looking at the most common genres, I can identify the types of content that appear most frequently. I also analyze content ratings to understand what kind of content is available for different age groups and audiences.
#
# The country-wise analysis is another interesting part of the project. It helps identify which countries contribute the most movies and TV shows to the platform. This gives an idea of how diverse and international Amazon Prime's content library is. Other information, such as movie duration, directors, and actors, can also be explored to find additional patterns in the dataset.
#
# To make the analysis easier to understand, I use different types of charts and graphs. Bar charts can be used to compare movies and TV shows or different genres, while line charts can show how the amount of content has changed over the years. Histograms and box plots can help understand movie durations, and other visualizations can be used to compare countries, ratings, and categories. These charts make it easier to identify patterns and explain the findings.
#
# The main goal of the project is not just to create charts but to understand what the data is telling us. For example, the analysis can help identify the most common genres, understand whether movies or TV shows dominate the platform, find the countries producing the most content, and observe how the content library has changed over the years. These findings can provide useful insights into the overall content strategy of the platform.
#
# For this project, I use Python along with libraries such as Pandas, NumPy, Matplotlib, and Seaborn. Pandas is mainly used for loading, cleaning, and analyzing the data, while Matplotlib and Seaborn are used to create different visualizations.
#
# Overall, this project gives me practical experience in working with a real-world dataset. It helps me understand the complete EDA process, starting from data cleaning and exploration to visualization and finding meaningful insights. The project also improves my ability to present data in a simple and understandable way and shows how data analysis can be used to better understand a business or entertainment platform.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Amazon Prime Video has a large collection of movies and TV shows from different countries, genres, and years. With such a wide variety of content, it can be difficult to understand the overall characteristics and trends of the platform’s content library.
#
# The purpose of this project is to analyze the Amazon Prime Video dataset and explore the different types of content available on the platform. The analysis will focus on factors such as movies and TV shows, genres, ratings, release years, countries, duration, and other available information.
#
# Using Exploratory Data Analysis (EDA), the project aims to identify important patterns and trends in the content library, understand how the content has changed over time, and generate meaningful insights from the available data. These insights can help in better understanding the platform's content distribution and overall content strategy.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# 1.To understand the distribution of movies and TV shows available on the platform.
#
# 2.To identify the most common and popular genres in the dataset.
#
# 3.To analyze the growth of content over the years and understand how the content library has changed.
#
# 4.To identify the countries that contribute the most content to Amazon Prime Video.
#
# 5.To analyze content ratings and understand the type of audience the platform serves.
#
# 6.To study movie durations and identify common content-length patterns.
#
# 7.To identify useful trends and patterns that can help in understanding Amazon Prime Video's content strategy.
#
# 8.To present the findings through clear and meaningful data visualizations so that the insights are easy to understand.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
sns.set_style("whitegrid")

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
titles = pd.read_csv('/content/drive/MyDrive/Data wrangling/titles.csv')
credits = pd.read_csv('/content/drive/MyDrive/Data wrangling/credits.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
titles.head()
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %%
credits.head()
# Out:
#    person_id       id           name      character   role
# 0      59401  ts20945     Joe Besser            Joe  ACTOR
# 1      31460  ts20945     Moe Howard            Moe  ACTOR
# 2      31461  ts20945     Larry Fine          Larry  ACTOR
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
titles.shape
# Out:
# (9871, 15)

# %%
credits.shape
# Out:
# (124235, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# ...

# %%
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124235 entries, 0 to 124234
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   person_id  124235 non-null  int64
#  1   id         124235 non-null  object
#  2   name       124235 non-null  object
#  3   character  107948 non-null  object
#  4   role       124235 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
titles.duplicated().sum()
# Out:
# np.int64(3)

# %%
credits.duplicated().sum()
# Out:
# np.int64(56)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
titles.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64

# %%
credits.isnull().sum()
# Out:
# person_id        0
# id               0
# name             0
# character    16287
# role             0
# dtype: int64

# %%
# Visualizing the missing values

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# From the first view of the data I have found that there are 9871 rows and 15 columns in titles and there are 124235 rows and 15 columns in credits.I have checked datasets for the duplicate values and found that there are 3 duplicate values in titles and 56 duplicate values in credits.We also found the null values in titles dataframe and found following null values -
#
# description - 119,age_certification - 6487,seasons - 8514, imdb_id - 667,imdb_score - 1021,imdb_votes - 1031,tmdb_popularity - 547,
# tmdb_score - 2082

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
titles.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
credits.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
# Dataset Describe
titles.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   9871.000000  9871.000000  1357.000000  8850.000000  8.840000e+03
# mean    2001.327221    85.973052     2.791452     5.976395  8.533614e+03
# std       25.810071    33.512466     4.148958     1.343842  4.592015e+04
# min     1912.000000     1.000000     1.000000     1.100000  5.000000e+00
# 25%     1995.500000    65.000000     1.000000     5.100000  1.170000e+02
# 50%     2014.000000    89.000000     1.000000     6.100000  4.625000e+02
# 75%     2018.000000   102.000000     3.000000     6.900000  2.236250e+03
# max     2022.000000   549.000000    51.000000     9.900000  1.133692e+06
#
#        tmdb_popularity   tmdb_score
# count      9324.000000  7789.000000
# mean          6.910204     5.984247
# std          30.004098     1.517986
# min           0.000011     0.800000
# 25%           1.232000     5.100000
# 50%           2.536000     6.000000
# 75%           5.634000     6.900000
# ...

# %%
credits.describe()
# Out:
#           person_id
# count  1.242350e+05
# mean   4.064737e+05
# std    5.616296e+05
# min    1.000000e+00
# 25%    3.899200e+04
# 50%    1.339490e+05
# 75%    5.712560e+05
# max    2.371153e+06

# %% [markdown]
# ### Variables Description

# %% [markdown]
# This project has two datasets -- titles and credits. Titles has variables as title, type (Movie/Show), release_year, runtime, genres, age_certification, production_countries, imdb_score, and tmdb_popularity.
# The credits dataset provides information on the people involved in the content, including name, character, and role (Actor, Director, or Writer)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
titles.nunique()
# Out:
# id                      9868
# title                   9737
# type                       2
# description             9734
# release_year             110
# age_certification         11
# runtime                  207
# genres                  2028
# production_countries     497
# seasons                   32
# imdb_id                 9201
# imdb_score                86
# imdb_votes              3650
# tmdb_popularity         5325
# tmdb_score                89
# dtype: int64

# %%
credits.nunique()
# Out:
# person_id    80508
# id            8861
# name         79758
# character    71097
# role             2
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Replace NaN values with 'Not Rated' in age_certification column
titles['age_certification'].fillna('Not Rated', inplace=True)

# Replace NaN values in imdb_score with mean values
titles['imdb_score'].fillna(titles['imdb_score'].mean(), inplace=True)

# Dropping duplicate values from titles and credits
titles.drop_duplicates(inplace = True)
credits.drop_duplicates(inplace = True)

# merging titles and credits datasets
merged_df = titles.merge(credits,on = 'id', how = 'left')

# Creating a column for decade
titles['decade'] = (titles['release_year'] // 10)*10

# categorize runtime into short,medium,long
merged_df['runtime_category'] = ''
for i in range(len(merged_df)):
    if merged_df.loc[i,'runtime'] < 30:
      merged_df.loc[i,'runtime_category'] = 'short'
    elif merged_df.loc[i,'runtime'] <= 90:
      merged_df.loc[i,'runtime_category'] = 'medium'
    else:
      merged_df.loc[i,'runtime_category'] = 'long'

# add col is_movie(movie = 1,show = 0)
merged_df['ismovie'] = 0
for i in range(len(merged_df)):
  if merged_df.loc[i,'type'] == 'MOVIE':
    merged_df.loc[i,'ismovie'] = 1
  else:
    merged_df.loc[i,'ismovie'] = 0

# %%
# categorize imdb rating to poor,good,excellent
merged_df['rating_category'] = ''
for i in range(len(merged_df)):
  score = merged_df.loc[i,'imdb_score']
  if pd.isna(score):
    merged_df.loc[i,'rating_category'] = 'Not Rated'
  elif score < 5:
    merged_df.loc[i,'rating_category'] = 'poor'
  elif score < 7:
    merged_df.loc[i,'rating_category'] = 'Average'
  elif score < 8.5:
    merged_df.loc[i,'rating_category'] = 'Good'
  else:
    merged_df.loc[i,'rating_category'] = 'Excellent'

# %%
# general kpi
total_titles = merged_df.shape[0]
total_movies = merged_df[merged_df['type'] == 'MOVIE'].shape[0]
total_shows = merged_df[merged_df['type'] == 'SHOW'].shape[0]
avg_runtime = merged_df['runtime'].mean()
avg_imdb = merged_df['imdb_score'].mean()
oldest_year = merged_df['release_year'].min()
newest_year = merged_df['release_year'].max()

print('Total Titles : ',total_titles)
print('Total Movies : ',total_movies)
print('Total Shows : ',total_shows)
print('Average Runtime : ',avg_runtime)
print('Average IMDB : ',avg_imdb)
print('Oldest Year : ',oldest_year)
print('Newest Year : ',newest_year)
# Out:
# Total Titles :  125186
# Total Movies :  116685
# Total Shows :  8501
# Average Runtime :  95.3480181489943
# Average IMDB :  5.971655057455298
# Oldest Year :  1912
# Newest Year :  2022

# %%
#Genre Based KPIs

# Split multiple genres into separate rows
genres_split = merged_df.dropna(subset=['genres']).copy()
genres_split['genres'] = genres_split['genres'].str.replace('[', '').str.replace(']', '').str.replace("'", "")
genres_split = genres_split.assign(genres=genres_split['genres'].str.split(','))
genres_split = genres_split.explode('genres')
genres_split['genres'] = genres_split['genres'].str.strip()

# Top 10 genres
top_genres = genres_split['genres'].value_counts().head(10)
print(top_genres)

# Average IMDb by genre
avg_imdb_genre = genres_split.groupby('genres')['imdb_score'].mean().sort_values(ascending=False).head(10)
print(avg_imdb_genre)
# Out:
# genres
# drama       70006
# comedy      41493
# thriller    33079
# action      30400
# romance     28633
# crime       20618
# horror      14142
# european    12548
# scifi       11442
# fantasy      8935
# Name: count, dtype: int64
# genres
# documentation    6.874880
# history          6.682058
# reality          6.573309
# war              6.429377
# animation        6.380818
# european         6.336190
# sport            6.256898
# drama            6.228907
# romance          6.121547
# music            6.116504
# Name: imdb_score, dtype: float64

# %%
#Ratings & Quality KPIs

# Average IMDb and TMDB
avg_imdb = merged_df['imdb_score'].mean()
avg_tmdb = merged_df['tmdb_score'].mean()
print("Average IMDb:", round(avg_imdb,2), "Average TMDB:", round(avg_tmdb,2))

# Top 10 highest rated
top_rated = merged_df.sort_values('imdb_score', ascending=False).head(10)
print(top_rated[['title', 'imdb_score']])

# Correlation between IMDb and TMDB
correlation = merged_df['imdb_score'].corr(merged_df['tmdb_score'])
print("Correlation IMDb vs TMDB:", round(correlation,2))
# Out:
# Average IMDb: 5.97 Average TMDB: 5.99
#              title  imdb_score
# 119807  Pawankhind         9.9
# 119812  Pawankhind         9.9
# 119808  Pawankhind         9.9
# 119814  Pawankhind         9.9
# 119813  Pawankhind         9.9
# 119798  Pawankhind         9.9
# 119799  Pawankhind         9.9
# 119815  Pawankhind         9.9
# 119797  Pawankhind         9.9
# 119800  Pawankhind         9.9
# Correlation IMDb vs TMDB: 0.62

# %%
#Cast and Crew KPIs

# Top actors, directors, and writers
top_actors = merged_df[merged_df['role'] == 'ACTOR']['name'].value_counts().head(10)
top_directors = merged_df[merged_df['role'] == 'DIRECTOR']['name'].value_counts().head(10)
top_writers = merged_df[merged_df['role'] == 'WRITER']['name'].value_counts().head(10)

print("Top Actors:\n", top_actors)
print("Top Directors:\n", top_directors)
print('Top Writers:\n',top_writers)

# Role distribution
role_dist = merged_df['role'].value_counts()
print(role_dist)
# Out:
# Top Actors:
#  name
# George 'Gabby' Hayes    49
# Roy Rogers              45
# Bess Flowers            44
# Gene Autry              40
# Nassar                  37
# Herman Hack             35
# Charles King            35
# George Morrell          34
# Earl Dwire              34
# Forrest Taylor          34
# Name: count, dtype: int64
# Top Directors:
#  name
# Joseph Kane           41
# Sam Newfield          38
# Jay Chapman           34
# Lesley Selander       22
# John English          21
# Harry L. Fraser       21
# William Nigh          20
# Manny Rodriguez       17
# Robert N. Bradbury    17
# George Archainbaud    16
# Name: count, dtype: int64
# Top Writers:
#  Series([], Name: count, dtype: int64)
# role
# ACTOR       115793
# DIRECTOR      8386
# Name: count, dtype: int64

# %%
#Country and Regional KPIs

# Split production countries
countries_split = merged_df.dropna(subset=['production_countries']).copy()
countries_split['production_countries'] = countries_split['production_countries'].str.replace('[', '').str.replace(']', '').str.replace("'", "")
countries_split = countries_split.assign(production_countries=countries_split['production_countries'].str.split(','))
countries_split = countries_split.explode('production_countries')
countries_split['production_countries'] = countries_split['production_countries'].str.strip()

# Top 10 countries
top_countries = countries_split['production_countries'].value_counts().head(10)
print(top_countries)
# Out:
# production_countries
# US    79111
# GB    12574
# IN    11591
# CA     6625
# FR     4861
# DE     3219
#        2745
# JP     2650
# IT     2578
# AU     2195
# Name: count, dtype: int64

# %%
#Age Certification KPIs

# Count of each certification
cert_count = merged_df['age_certification'].value_counts()
print(cert_count)

# Average IMDb by certification
avg_imdb_cert = merged_df.groupby('age_certification')['imdb_score'].mean().sort_values(ascending=False)
print(avg_imdb_cert)
# Out:
# age_certification
# Not Rated    68329
# R            25941
# PG-13        12506
# PG            9641
# G             3845
# TV-MA         1743
# TV-14         1605
# TV-PG          519
# TV-Y7          365
# TV-Y           320
# TV-G           255
# NC-17          117
# Name: count, dtype: int64
# age_certification
# TV-PG        7.454458
# TV-MA        7.357626
# TV-14        7.234761
# TV-Y7        6.738242
# TV-G         6.634831
# TV-Y         6.410660
# PG-13        6.107513
# PG           6.102564
# G            6.039746
# R            5.923611
# Not Rated    5.858963
# NC-17        5.300653
# Name: imdb_score, dtype: float64

# %%
#Popularity and Engagement KPIs

# Top 10 popular titles
top_popular = merged_df.sort_values('tmdb_popularity', ascending=False).head(10)
print(top_popular[['title', 'tmdb_popularity']])

# Correlation between popularity & IMDb
popularity_corr = merged_df['tmdb_popularity'].corr(merged_df['imdb_score'])
print("Correlation between TMDB Popularity and IMDb Rating:", round(popularity_corr,2))
# Out:
#                      title  tmdb_popularity
# 116570  All the Old Knives         1437.906
# 116569  All the Old Knives         1437.906
# 116568  All the Old Knives         1437.906
# 116567  All the Old Knives         1437.906
# 116566  All the Old Knives         1437.906
# 116565  All the Old Knives         1437.906
# 116564  All the Old Knives         1437.906
# 116586  All the Old Knives         1437.906
# 116585  All the Old Knives         1437.906
# 116584  All the Old Knives         1437.906
# Correlation between TMDB Popularity and IMDb Rating: 0.07

# %%
#Time and Trends KPIs

# Number of releases per year
release_trend = merged_df['release_year'].value_counts().sort_index()

# Average IMDb per year
avg_imdb_year = merged_df.groupby('release_year')['imdb_score'].mean()

# %%
#Derived KPIs (from feature engineered columns)

# Average runtime by runtime category
avg_runtime_category = merged_df.groupby('runtime_category')['runtime'].mean()
print(avg_runtime_category)

# Average IMDb by rating category
avg_rating_category = merged_df.groupby('rating_category')['imdb_score'].mean()
print(avg_rating_category)
# Out:
# runtime_category
# long      113.521213
# medium     74.748500
# short      21.836796
# Name: runtime, dtype: float64
# rating_category
# Average      5.991743
# Excellent    8.729434
# Good         7.474342
# poor         4.087871
# Name: imdb_score, dtype: float64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# In Data Wrangling,I first fill the null values in the age_certification with "Not rated" and imdb_score with mean of this column.Then I dropped the duplicates in titles and credits dataframe and then merged this two dataframes.Three new colums were added named runtime_category,rating_category and ismovie.After that I mentioned general kpi as - total_titles,total_movies,total_shows,avg_runtime,avg_imdb,oldest_year,newest_year.
#
# These kpi's will be useful when we do visualization.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
merged_df['type'].value_counts().plot(kind = 'bar',color = ['skyblue','orange'])
plt.title('Distribution of Movies and TV Shows on Amazon Prime')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a bar chart because type contains the categorial data (i.e.MOVIE and SHOW).Bar chart makes it easier to compare the number of titles in each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the distribution of Movies vs. TV Shows available on Amazon Prime. It helped identify Movies has a larger share of the content library and the platform's content is more focused on Movies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Since Movies have a higher count than TV Shows, Amazon Prime has a stronger focus on movie content. This can help the business understand its current content strategy and plan future investments accordingly.
#
# Also,the lower number of TV Shows may represent a potential area for growth.

# %% [markdown]
# #### Chart - 2 Release by year

# %%
# Release by year
merged_df['release_year'].value_counts().sort_index().plot(kind = 'line',color = 'green')
plt.title('Release of Movies and TV Shows on Amazon Prime by Year')
plt.xlabel('Release Year')
plt.ylabel('Count of Titles')
# Out:
# Text(0, 0.5, 'Count of Titles')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a line chart because release_year contains numerical and time-based data. A line chart makes it easier to observe the trend and changes in the number of titles released over different years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the number of Movies and TV Shows released on Amazon Prime by year. It helps identify the years with higher or lower content releases. The chart indicates that the number of titles generally increased in between 2000-2020, showing an expansion of the content library.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The increasing number of titles in recent years indicates that Amazon Prime is expanding its content library, which can help attract new viewers and retain existing subscribers by providing more content choices.

# %% [markdown]
# #### Chart - 3 Runtime Distribution

# %%
# Runtime Distribution
plt.hist(merged_df['runtime'].dropna(),bins=30,color='orange',edgecolor='black')
plt.title('Distribution of Movie Runtimes on Amazon Prime')
plt.xlabel('Runtime (minutes)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a histogram because runtime contains numerical data measured in minutes. A histogram makes it easier to understand the distribution of movie runtimes and identify the most common runtime range.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the distribution of movie runtimes on Amazon Prime. It helps identify the runtime range 80-120 in which most movies are concentrated. From the chart, most movies have a moderate runtime, while very short and very long movies are less common.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding the common movie runtime can help Amazon Prime in content planning and acquisition by identifying the runtime preferences represented in its existing library. This can help the platform maintain a suitable variety of movie lengths for different types of viewers.

# %% [markdown]
# #### Chart - 4 Top 10 Genres by count

# %%
genres_split['genres'].value_counts().head().plot(kind='bar',color = 'purple')
plt.title('Top 10 Genres by Count')
plt.xlabel('Genre')
plt.ylabel('Count of Titles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a bar chart because genres contains categorical data. A bar chart makes it easier to compare the number of titles across different genres and identify the most popular genres in the Amazon Prime content library.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the top genres based on the number of titles available on Amazon Prime. It helps identify drama genre has the largest presence in the content library. This gives an understanding of the content preferences and focus areas of the platform.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. These insights can help Amazon Prime understand which genres have a strong presence in its content library and use this information when planning future content acquisition and production.

# %% [markdown]
# #### Chart - 5 Average IMDB by Genres(Top 10)

# %%
avg_imdb_genre.head(10).plot(kind='bar',color = 'teal')
plt.title('Average IMDb by Genres')
plt.xlabel('Genre')
plt.ylabel('Average IMDb Score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a bar chart because Genre is categorical data and Average IMDb Score is numerical data. A bar chart makes it easier to compare the average IMDb ratings across different genres.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the average IMDb score for different genres on Amazon Prime are almost same. This gives an understanding of the genres associated with better-rated content.Documentation has the highest IMDb Score.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights can help Amazon Prime identify genres that have higher average IMDb scores and consider these genres when planning future content acquisition or production.
#
# Genres with relatively lower average IMDb scores may represent a potential area for improvement. Amazon Prime could focus on acquiring or producing higher-quality content in these genres to improve viewer satisfaction.

# %% [markdown]
# #### Chart - 6 Genres vs IMDB Heatmap

# %%
genre_pivot = genres_split.pivot_table(index='genres', values='imdb_score', aggfunc='mean').sort_values('imdb_score', ascending=False).head(15)
sns.heatmap(genre_pivot, annot=True, cmap='pink')
plt.title('Average IMDb Rating by Genre')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a heatmap because it makes it easy to compare the average IMDb ratings across multiple genres. The color intensity helps quickly identify genres with higher and lower average IMDb scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the average IMDb rating of the top 15 genres on Amazon Prime. The genres with higher IMDb ratings(i.e. Documentation,history,reality) indicate that the content in those genres has a better average audience rating, while genres with lower ratings have relatively lower average scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight can help Amazon Prime identify genres with higher-rated content and use this information when making future content acquisition and production decisions.
#
# Genres with comparatively lower IMDb ratings may represent a potential area for improvement. Amazon Prime can focus on improving the quality of content in these genres to increase viewer satisfaction.

# %% [markdown]
# #### Chart - 7 IMDB Score Distribution

# %%
sns.histplot(merged_df['imdb_score'], bins=20, kde=True, color='teal')
plt.title('Distribution of IMDb Scores')
plt.xlabel('IMDb Score')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a histogram with KDE because imdb_score is numerical data. The histogram makes it easier to understand the distribution of IMDb scores, while the KDE curve helps identify the overall pattern and concentration of the ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how IMDb scores are distributed across the Movies and TV Shows available on Amazon Prime. It helps identify the most common range of IMDb scores which is between 5 to 7 and whether the ratings are concentrated around a particular score or spread across a wider range.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The distribution of IMDb scores can help Amazon Prime understand the overall quality and audience reception of its content. If most titles have moderate to high IMDb scores, it indicates that a significant portion of the content is well-rated.
#
# If a large number of titles have lower IMDb scores, this could represent a potential area for improvement. Amazon Prime could focus on acquiring or producing higher-quality content to improve viewer satisfaction and strengthen its content library.

# %% [markdown]
# #### Chart - 8 IMDB vs TMDb scatter plot

# %%
sns.scatterplot(data=merged_df, x='imdb_score', y='tmdb_score', color='coral')
plt.title('IMDb vs TMDB Score Correlation')
plt.xlabel('IMDb Score')
plt.ylabel('TMDB Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a scatter plot because both imdb_score and tmdb_score are numerical data. A scatter plot makes it easier to identify the relationship or correlation between IMDb and TMDB scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the relationship between IMDb scores and TMDB scores for Amazon Prime titles. There are many points clustered around IMDb 4-8 and TMDB 3-8. The points show that titles with higher IMDb scores generally tend to have higher TMDB scores, indicating a positive relationship between the two rating platforms.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The positive relationship between IMDb and TMDB scores can help Amazon Prime understand that well-rated content on one platform tends to receive good ratings on the other platform as well. This can be useful when evaluating the overall audience reception of content.
#
# There is no direct indication of negative growth from this chart because it shows the relationship between two rating systems rather than business growth over time. However, titles with consistently lower ratings on both platforms may represent a potential area for improvement in content quality.

# %% [markdown]
# #### Chart - 9 Top 10 Actors

# %%
top_actors.plot(kind='barh',color = 'green')
plt.title('Top 10 Actors')
plt.xlabel('Actor')
plt.ylabel('Count of Titles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a horizontal bar chart because Actor is categorical data and Count of Titles is numerical data. A horizontal bar chart makes it easier to compare the number of titles associated with the top 10 actors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the top 10 actors based on their number of titles on Amazon Prime. George 'Gabby' Hayes has the highest count,while Forrest Taylor has the lowest among the top 10. The actor with the highest count has contributed to or appeared in more titles compared to the other actors shown.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight can help Amazon Prime identify actors who are frequently represented in its content library. This information can be useful for understanding casting patterns and planning future content.
#
# Actors with fewer appearances among the top 10 may represent an opportunity to diversify the talent pool and introduce more actors to the platform. This can provide viewers with greater variety and does not necessarily indicate negative growth.

# %% [markdown]
# #### Chart - 10 Top 10 Directors

# %%
top_directors.plot(kind='barh',color = 'plum')
plt.title('Top 10 Directors')
plt.xlabel('Director')
plt.ylabel('Count of Titles')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a horizontal bar chart because Director is categorical data and Count of Titles is numerical data. A horizontal bar chart makes it easier to compare the number of titles directed by the top 10 directors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the top 10 directors based on their number of titles on Amazon Prime. Joseph Kane contributed to the highest number of titles in the content library. The director with the highest count has directed more titles compared to the other directors shown.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight can help Amazon Prime identify directors with a strong presence in its content library and understand its existing content-creation patterns. This information can be useful when planning future content and collaborations.
#
# Directors with fewer titles among the top 10 may represent an opportunity to diversify the director pool and bring different creative styles to the platform. This could increase content variety and does not directly indicate negative growth.

# %% [markdown]
# #### Chart - 11 Role Distribution

# %%
role_dist.plot(kind='pie',autopct='%1.1f%%',startangle =90,color = ['purple','coral','gold'])
plt.title('Role Distribution (Actor, Director, Writer)')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a pie chart because role_dist represents categorical data divided into different roles such as Actor, Director, and Writer. A pie chart makes it easy to understand the percentage contribution of each role to the total.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the distribution of Actors, Directors, and Writers in the Amazon Prime dataset. Actors has the largest share of 93.2% and Directors has smaller share of 6.8% in the overall content contribution.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight can help Amazon Prime understand the composition of creative roles involved in its content library. It can support decisions related to content production, talent acquisition, and resource planning.
#
# If one role has a much higher share than the others, the lower representation of other roles may be a potential area for diversification. Increasing diversity across roles can help bring different creative perspectives and contribute to a wider variety of content.

# %% [markdown]
# #### Chart - 12 Top 10 Production Countries

# %%
top_countries.plot(kind = 'bar',color='teal')
plt.title('Top 10 Production Countries')
plt.xlabel('Production Country')
plt.ylabel('Count of Titles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a bar chart because Production Country is categorical data and Count of Titles is numerical data. A bar chart makes it easier to compare the number of titles produced by different countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the top 10 production countries based on the number of titles available on Amazon Prime. It helps identify US contribute the largest number of titles to the platform's content library. The country with the highest count has the largest contribution among the countries shown.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight can help Amazon Prime understand which countries are major contributors to its content library. This can support decisions related to international content acquisition and production.
#
# Countries with fewer titles may represent a potential area for expansion. Increasing content from different countries can help Amazon Prime provide more diverse and region-specific content to viewers. This can also help the platform reach audiences with different cultural and language preferences.

# %% [markdown]
# #### Chart - 13 Top 10 Countries by avg Imdb rating

# %%
avg_imdb_country = countries_split.groupby('production_countries')['imdb_score'].mean().sort_values(ascending=False).head(10)
avg_imdb_country.plot(kind='bar',color = 'tomato')
plt.title('Top 10 Countries by Average IMDb Rating')
plt.xlabel('Country')
plt.ylabel('Average IMDb Rating')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a bar chart because Country is categorical data and Average IMDb Rating is numerical data. A bar chart makes it easier to compare the average IMDb ratings of different production countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the top 10 production countries based on their average IMDb rating. It helps identify AL have content with higher average IMDb ratings in the Amazon Prime dataset. The country with the highest average rating has the highest average IMDb score among the countries shown.Almost all countries has rating between 7-8.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight can help Amazon Prime identify countries that are associated with higher-rated content and consider these markets when planning future content acquisition and production.
#
# Countries with comparatively lower average IMDb ratings among the selected countries may represent a potential area for improvement in content quality. Amazon Prime can focus on improving or carefully selecting content from these markets to maintain a high-quality content library.

# %% [markdown]
# #### Chart - 14 - Aberage IMDB by Certification

# %%
avg_imdb_cert.plot(kind ='bar',color='orchid')
plt.title('Average IMDb Rating by Age Certification')
plt.xlabel('Age Certification')
plt.ylabel('Average IMDb Rating')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a bar chart because Age Certification is categorical data and Average IMDb Rating is numerical data. A bar chart makes it easier to compare the average IMDb ratings across different age certifications.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the average IMDb rating for different age certifications on Amazon Prime. It helps identify TV-PG age-certified content has higher  average IMDb ratings and provides an understanding of how content ratings vary across different audience categories.First three age_certification has higher ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight can help Amazon Prime understand which age-certified content receives higher average ratings and use this information when planning future content acquisition and production.
#
# Age certifications with comparatively lower average IMDb ratings may represent a potential area for improvement. Amazon Prime can focus on improving the quality of content in these categories while maintaining a diverse range of content for different age groups.

# %% [markdown]
# #### Chart - 15 - Popularity vs IMDb sactterplot

# %%
sns.scatterplot(data=merged_df, x='tmdb_popularity', y='imdb_score', color='darkgreen')
plt.title('Popularity vs IMDb Score')
plt.xlabel('TMDB Popularity')
plt.ylabel('IMDb Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a scatter plot because both tmdb_popularity and imdb_score are numerical data. A scatter plot makes it easier to identify the relationship between a title's popularity and its IMDb score.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the relationship between TMDB popularity and IMDb scores of Amazon Prime titles. It helps identify whether highly popular titles also tend to have higher IMDb ratings. The points show that popularity and IMDb rating do not always increase together, meaning a highly popular title may not necessarily have a high IMDb score.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight can help Amazon Prime understand that popularity and content quality are different factors. A title can receive high audience attention without having a very high IMDb rating.
#
# This can help Amazon Prime make better decisions by considering both popularity and audience ratings when evaluating content. Titles with high popularity but relatively lower IMDb scores may represent a potential area for improvement in content quality, while highly rated but less popular titles may benefit from better marketing and promotion.

# %% [markdown]
# #### Chart - 16 - IMDB votes Trend(if avalable)

# %%
if 'imdb_votes' in merged_df.columns:
  merged_df.groupby('release_year')['imdb_votes'].mean().plot(kind='line', color='blue')
  plt.title('Average IMDb Votes per Year')
  plt.xlabel('Year')
  plt.ylabel('Average Votes')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a line chart because release_year represents time-based data and imdb_votes is numerical data. A line chart makes it easier to observe changes and trends in the average number of IMDb votes over different years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the average number of IMDb votes received by titles released in each year. It helps identify year 2000 where titles received higher audience engagement based on the number of IMDb votes. Changes in the line can also show how audience interaction with the content has varied over time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight can help Amazon Prime understand audience engagement with its content over different years. Years with higher average IMDb votes indicate greater audience interaction, which can help in understanding viewer interest and planning future content.
#
# Years with lower average IMDb votes may represent a potential area for improvement in audience engagement. Amazon Prime could focus on better content promotion and marketing to increase visibility and audience interaction. However, lower votes do not necessarily mean negative growth because newer titles may have had less time to accumulate votes.

# %% [markdown]
# #### Chart - 17 - Total Release Per Year

# %%
merged_df['release_year'].value_counts().sort_index().plot(kind='line', color='deepskyblue')
plt.title('Number of Releases Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a line chart because release_year represents time-based data and the number of titles is numerical data. A line chart makes it easier to observe the trend in the number of releases over different years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how the number of Movies and TV Shows released has changed over the years on Amazon Prime. It helps identify periods with higher and lower numbers of releases and shows the overall trend of content production and availability over time.In year 2000 to 2020, we can see that there are higher number of releases.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight can help Amazon Prime understand its content release trend and plan future content production and acquisition accordingly. A higher number of releases indicates an expansion of the content library, which can provide viewers with more choices.
#
# Years with a lower number of releases may represent a potential area for growth. Amazon Prime can focus on maintaining a consistent flow of new content to keep viewers engaged and strengthen its content library.

# %% [markdown]
# #### Chart - 18 - Avg IMDB Rating over the years

# %%
avg_imdb_year.plot(kind='line', color='navy')
plt.title('Average IMDb Rating Over the Years')
plt.xlabel('Year')
plt.ylabel('Average IMDb Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a line chart because Year represents time-based data and Average IMDb Score is numerical data. A line chart makes it easier to observe the trend and changes in average IMDb ratings over the years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how the average IMDb rating of Movies and TV Shows has changed over the years on Amazon Prime. It helps identify years with higher or lower average ratings and shows whether the overall content quality, based on IMDb scores, has remained stable, increased, or decreased over time.around year 1920, there are higher IMDb score.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight can help Amazon Prime monitor the quality of its content over time. If the average IMDb rating remains high or increases, it indicates that the platform is maintaining or improving the quality of its content.
#
# Years with a lower average IMDb rating may represent a potential area for improvement. Amazon Prime can focus on acquiring or producing higher-quality content to improve viewer satisfaction and maintain a strong content library.

# %% [markdown]
# #### Chart - 19 - Runtime Trend Over Year

# %%
sns.lineplot(data=merged_df,x='release_year',y='runtime',color='darkred')
plt.title('Avg Runtime Over Year')
plt.xlabel('Year')
plt.ylabel('Runtime')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a line chart because release_year represents time-based data and runtime is numerical data. A line chart makes it easier to observe how the runtime of titles has changed over the years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the change in average runtime of Movies and TV Shows over different years on Amazon Prime. It helps identify whether the runtime of content has generally increased, decreased, or remained relatively stable over time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight can help Amazon Prime understand changes in viewer content formats and runtime patterns over the years. This can support decisions about the type and length of content to acquire or produce.
#
# If the average runtime is increasing significantly, it may indicate an opportunity to provide more shorter and easily consumable content for viewers who prefer quick entertainment. Similarly, if runtime is decreasing, Amazon Prime can consider maintaining a balance between shorter and longer content. These trends do not directly indicate negative growth but can highlight opportunities to improve content variety.

# %% [markdown]
# #### Chart - 20 - Average IMDB by Rating Category

# %%
avg_rating_category.plot(kind='bar',color='salmon')
plt.title('Average IMDb Rating by Rating Category')
plt.xlabel('Rating Category')
plt.ylabel('Average IMDb Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a bar chart because Rating Category is categorical data and Average IMDb Rating is numerical data. A bar chart makes it easier to compare the average IMDb ratings across different rating categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the average IMDb rating for each rating category on Amazon Prime. It helps identify excellent category has higher average IMDb scores and provides an overview of the content quality across different categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight can help Amazon Prime understand which rating categories have better audience ratings and use this information while planning future content acquisition and production.
#
# Rating categories with comparatively lower average IMDb ratings may represent a potential area for improvement. Amazon Prime can focus on improving the quality of content in these categories to increase viewer satisfaction. However, lower ratings do not directly indicate negative growth; they mainly highlight an opportunity to improve content quality.

# %% [markdown]
# #### Chart - 21 - Average Runtime by Runtime Category

# %%
avg_runtime_category.plot(kind='bar',color='lightblue')
plt.title('Average Runtime by Runtime Category')
plt.xlabel('Runtime Category')
plt.ylabel('Average Runtime')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a bar chart because Runtime Category is categorical data and Average Runtime is numerical data. A bar chart makes it easier to compare the average runtime across different runtime categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the average runtime for each runtime category on Amazon Prime. It helps identify long categorie has longer average runtimes and provides an understanding of the runtime pattern of the content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight can help Amazon Prime understand the runtime preferences represented in its content library and support decisions about future content production and acquisition.
#
# Categories with lower average runtimes may provide opportunities to offer shorter, easy-to-consume content, while categories with longer runtimes can serve viewers who prefer more detailed content. Maintaining a variety of runtimes can help Amazon Prime meet different viewer preferences. Lower or higher runtime does not directly indicate negative growth.

# %% [markdown]
# #### Chart - 22 - Runtime vs IMDB Scatterplot

# %%
sns.scatterplot(data=merged_df, x='runtime', y='imdb_score', color='purple')
plt.title('Runtime vs IMDb Score')
plt.xlabel('Runtime')
plt.ylabel('IMDb Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I used a scatter plot because both runtime and imdb_score are numerical data. A scatter plot makes it easier to observe the relationship between the runtime of a title and its IMDb score.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the relationship between runtime and IMDb score for Amazon Prime titles.There are many points clustered around IMDb 4-8 and runtime 0-200. The points show that there is no clear strong relationship between runtime and IMDb score, meaning runtime alone does not determine how highly a title is rated.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight can help Amazon Prime understand that content quality and audience ratings are not necessarily dependent on runtime. Therefore, Amazon Prime can focus on content quality rather than assuming that longer or shorter titles will automatically receive better ratings.
#
# There is no direct indication of negative growth from this chart. However, the lack of a strong relationship suggests that simply changing the runtime may not improve IMDb ratings; content quality and audience preferences should also be considered.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Amazon Prime can achieve its business goals by using data insights to identify and invest in the genres and regions that attract the largest audiences. Focusing on popular and highly rated content, along with working with well-known directors and actors, can help increase viewer interest and engagement. The platform can also use IMDb and TMDB ratings to understand audience preferences and provide more relevant personalized recommendations. Offering a combination of recently released content and classic movies or shows can further help Amazon Prime appeal to viewers with different interests. By applying these data-driven strategies, Amazon Prime can improve its content offerings, increase customer loyalty, and strengthen its position in the global streaming industry.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Exploratory Data Analysis of Amazon Prime offered useful insights into its content patterns, viewer interests, and overall performance. The analysis showed that elements such as genre demand, the distribution of release years, and IMDb and TMDB ratings can influence the popularity and performance of movies and shows. Examining ratings, content types, and contributions from different regions also helped identify potential areas for improving Amazon Prime’s content planning and audience targeting. These insights can support better decisions regarding future content investments, enhance the viewing experience, and help the platform remain competitive in the rapidly changing streaming market. Overall, the analysis demonstrates how data and analytics can support strategic decision-making and contribute to business growth in the entertainment industry.
